# %% [markdown]
# ### Neural Network Architecture
# * (3x3) | 32
# * (3x3) | 64
# * Dense | 128
# * Dense | 128
# * Dense | 4
#
# ### Training Set
# * 7033 : Eye Centers

# %%
# !ls
# Out:
# datalab  drive

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install -q keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential, load_model
from keras.layers import BatchNormalization, Conv2D, Activation, MaxPooling2D, Dense, Flatten, Dropout, GlobalAveragePooling2D
from keras import optimizers
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("drive/facial-landmark-detection/training.csv")

# %%
df.shape
# Out:
# (7049, 31)

# %%
df2 = df.iloc[:,[0,1,2,3,30]]
df2 = df2.dropna()
df2.shape
# Out:
# (7033, 5)

# %%
imageStringList = []
imageStringList.extend(df2.loc[:,"Image"])

# converting the strings to numpy arrays
print "[INFO] Converting string enteries to images"
imageList = []
index=0
for s in imageStringList:
	imageList.append(np.array([int (e) for e in s.split(" ")]).reshape((96,96)))
	index = index + 1
	if index%500 == 0 :
		print str(index) + " images converted"
# Out:
# [INFO] Converting string enteries to images
# 500 images converted
# 1000 images converted
# 1500 images converted
# 2000 images converted
# 2500 images converted
# 3000 images converted
# 3500 images converted
# 4000 images converted
# 4500 images converted
# 5000 images converted
# 5500 images converted
# 6000 images converted
# 6500 images converted
# 7000 images converted

# %%
def invert(X1):
    xTemp = np.copy(X1)
    xTemp2 = np.copy(xTemp)
    
    for i in range(0,len(X1)) :
        xTemp2[i,:,:,0] = np.copy(np.fliplr(xTemp[i,:,:,0]))
    
    return xTemp2

def swap(Y):
    YTemp = np.copy(Y)

    col0 = np.copy(Y[:,0])
    col2 = np.copy(Y[:,2])
    YTemp[:,0] = col2
    YTemp[:,2] = col0
    
    col1 = np.copy(Y[:,1])
    col3 = np.copy(Y[:,3])
    YTemp[:,1] = col3
    YTemp[:,3] = col1
    
    return YTemp
  
def generate(modelDict) :
    # plotting the loss and metric for the model
    ax1 = plt.subplot(2,1,1)
    plt.plot(modelDict['mean_absolute_error'], linestyle='--', marker='o', color='b')
    plt.plot(modelDict['val_mean_absolute_error'], linestyle='--', marker='o', color='g')
    level1 = modelDict['mean_absolute_error'][0]
    level2 = modelDict['mean_absolute_error'][0] - 0.01
    i = 0
    for e in modelDict['mean_absolute_error']:
        if i%100==99 :
            e = round(e,4)
            ax1.annotate('('+str(i)+','+str(e)+')', xy=(i,level1), textcoords='data',color='b')
        i = i+1
    i = 0
    for e in modelDict['val_mean_absolute_error']:
        if i%100==99 :
            e = round(e,4)
            ax1.annotate('('+str(i)+','+str(e)+')', xy=(i,level2), textcoords='data',color='g')
        i = i+1
    plt.title('MAE | mean absolute error')
    plt.ylabel('mae')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower left')

    ax2 = plt.subplot(2,1,2)
    plt.plot(modelDict['loss'], linestyle='--', marker='o', color='b')
    plt.plot(modelDict['val_loss'], linestyle='--', marker='o', color='g')
    level1 = modelDict['loss'][0]
    level2 = modelDict['loss'][0] - 0.01
    i = 0
    for e in modelDict['loss']:
        if i%100==99 :
            e = round(e,4)
            ax2.annotate('('+str(i)+','+str(e)+')', xy=(i,level1), textcoords='data',color='b')
        i = i+1
    i = 0
    for e in modelDict['val_loss']:
        if i%100==99 :
            e = round(e,4)
            ax2.annotate('('+str(i)+','+str(e)+')', xy=(i,level2), textcoords='data',color='g')
        i = i+1
    plt.title('MSE | mean squared error')
    plt.ylabel('mse')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower left')

    # exporting the plot
    plt.tight_layout()
    fig = plt.gcf()
    fig.set_size_inches((16,9), forward=False)
    plt.show()

# %%
# preparing the training data
# input
X_temp = np.stack(imageList,axis=0)
X1 = X_temp.astype(np.float32)[:,:,:,np.newaxis] 				    # X1.shape = (7033,96,96,1)
#X2 = invert(X1)                                             # X2.shape = (7033,96,96,1)
#X = np.concatenate((X1[:-1404],X2[:-1404]),axis=0)
#X = np.concatenate((X,X1[-1404:],X2[-1404:]),axis=0)
X = X1

# output
Y1 = np.stack(df2.iloc[:,range(0,4)].values,axis=0) 	      # Y1.shape(7033,4)
#Y2 = swap(Y1)                                               # Y2.shape(7033,4)
#Y = np.concatenate((Y1[:-1404],Y2[:-1404]),axis=0)
#Y = np.concatenate((Y,Y1[-1404:],Y2[-1404:]),axis=0)
Y= Y1

# scaling input range to [0,1] from [0,255]
X = X.astype(np.float32)
X = X/255.0

# scaling target values to [-1,1] from [0,95]
Y = Y.astype(np.float32)
Y = (Y - 48.0)/48.0

# %%
X.shape
# Out:
# (7033, 96, 96, 1)

# %%
Y.shape
# Out:
# (7033, 4)

# %%
X, Y = shuffle(X, Y, random_state=42)  # shuffle data

# %%
# creating the ann model
model = Sequential()

model.add(BatchNormalization(input_shape=(96,96,1)))
# (96,96,1)

model.add(Conv2D(filters=32, kernel_size=(3,3), strides=(1,1)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# (47,47,32)

model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# (22,22,64)

model.add(Flatten())

model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(4))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 94, 94, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 94, 94, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 45, 45, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 4,000,904
# Trainable params: 4,000,902
# Non-trainable params: 2
# _________________________________________________________________

# %%
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_1000.h5')
# Out:
# [INFO] Training
# Train on 5626 samples, validate on 1407 samples
# Epoch 1/1000
# 5626/5626 [==============================] - 8s 1ms/step - loss: 0.8364 - mean_absolute_error: 0.4160 - val_loss: 0.0239 - val_mean_absolute_error: 0.1187
# Epoch 2/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0164 - mean_absolute_error: 0.0975 - val_loss: 0.0135 - val_mean_absolute_error: 0.0940
# Epoch 3/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0116 - mean_absolute_error: 0.0821 - val_loss: 0.0108 - val_mean_absolute_error: 0.0785
# Epoch 4/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0101 - mean_absolute_error: 0.0745 - val_loss: 0.0096 - val_mean_absolute_error: 0.0739
# Epoch 5/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0093 - mean_absolute_error: 0.0708 - val_loss: 0.0086 - val_mean_absolute_error: 0.0694
# Epoch 6/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0081 - mean_absolute_error: 0.0655 - val_loss: 0.0075 - val_mean_absolute_error: 0.0641
# Epoch 7/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0070 - mean_absolute_error: 0.0599 - val_loss: 0.0067 - val_mean_absolute_error: 0.0599
# Epoch 8/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0064 - mean_absolute_error: 0.0564 - val_loss: 0.0061 - val_mean_absolute_error: 0.0567
# Epoch 9/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0057 - mean_absolute_error: 0.0529 - val_loss: 0.0053 - val_mean_absolute_error: 0.0525
# Epoch 10/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0051 - mean_absolute_error: 0.0495 - val_loss: 0.0048 - val_mean_absolute_error: 0.0495
# Epoch 11/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0046 - mean_absolute_error: 0.0460 - val_loss: 0.0044 - val_mean_absolute_error: 0.0466
# Epoch 12/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0042 - mean_absolute_error: 0.0432 - val_loss: 0.0039 - val_mean_absolute_error: 0.0430
# Epoch 13/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0040 - mean_absolute_error: 0.0415 - val_loss: 0.0038 - val_mean_absolute_error: 0.0425
# Epoch 14/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0037 - mean_absolute_error: 0.0392 - val_loss: 0.0034 - val_mean_absolute_error: 0.0395
# Epoch 15/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0035 - mean_absolute_error: 0.0374 - val_loss: 0.0032 - val_mean_absolute_error: 0.0380
# Epoch 16/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0033 - mean_absolute_error: 0.0360 - val_loss: 0.0031 - val_mean_absolute_error: 0.0368
# Epoch 17/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0032 - mean_absolute_error: 0.0349 - val_loss: 0.0030 - val_mean_absolute_error: 0.0359
# Epoch 18/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 0.0031 - mean_absolute_error: 0.0344 - val_loss: 0.0029 - val_mean_absolute_error: 0.0356
# Epoch 19/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0030 - mean_absolute_error: 0.0334 - val_loss: 0.0029 - val_mean_absolute_error: 0.0351
# Epoch 20/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0029 - mean_absolute_error: 0.0326 - val_loss: 0.0028 - val_mean_absolute_error: 0.0341
# Epoch 21/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0028 - mean_absolute_error: 0.0319 - val_loss: 0.0028 - val_mean_absolute_error: 0.0340
# Epoch 22/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0027 - mean_absolute_error: 0.0316 - val_loss: 0.0027 - val_mean_absolute_error: 0.0331
# Epoch 23/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0027 - mean_absolute_error: 0.0312 - val_loss: 0.0029 - val_mean_absolute_error: 0.0355
# Epoch 24/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0027 - mean_absolute_error: 0.0316 - val_loss: 0.0026 - val_mean_absolute_error: 0.0328
# Epoch 25/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0026 - mean_absolute_error: 0.0307 - val_loss: 0.0027 - val_mean_absolute_error: 0.0333
# Epoch 26/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0026 - mean_absolute_error: 0.0312 - val_loss: 0.0027 - val_mean_absolute_error: 0.0340
# Epoch 27/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0026 - mean_absolute_error: 0.0312 - val_loss: 0.0028 - val_mean_absolute_error: 0.0345
# Epoch 28/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0025 - mean_absolute_error: 0.0302 - val_loss: 0.0025 - val_mean_absolute_error: 0.0317
# Epoch 29/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0024 - mean_absolute_error: 0.0298 - val_loss: 0.0026 - val_mean_absolute_error: 0.0330
# Epoch 30/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0024 - mean_absolute_error: 0.0292 - val_loss: 0.0025 - val_mean_absolute_error: 0.0315
# Epoch 31/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0023 - mean_absolute_error: 0.0289 - val_loss: 0.0026 - val_mean_absolute_error: 0.0326
# Epoch 32/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0023 - mean_absolute_error: 0.0287 - val_loss: 0.0025 - val_mean_absolute_error: 0.0319
# Epoch 33/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0023 - mean_absolute_error: 0.0287 - val_loss: 0.0025 - val_mean_absolute_error: 0.0318
# Epoch 34/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0023 - mean_absolute_error: 0.0288 - val_loss: 0.0025 - val_mean_absolute_error: 0.0316
# Epoch 35/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0022 - mean_absolute_error: 0.0278 - val_loss: 0.0024 - val_mean_absolute_error: 0.0309
# Epoch 36/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0021 - mean_absolute_error: 0.0279 - val_loss: 0.0025 - val_mean_absolute_error: 0.0317
# Epoch 37/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0021 - mean_absolute_error: 0.0279 - val_loss: 0.0024 - val_mean_absolute_error: 0.0311
# Epoch 38/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0022 - mean_absolute_error: 0.0285 - val_loss: 0.0026 - val_mean_absolute_error: 0.0324
# Epoch 39/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0021 - mean_absolute_error: 0.0274 - val_loss: 0.0024 - val_mean_absolute_error: 0.0309
# Epoch 40/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0021 - mean_absolute_error: 0.0275 - val_loss: 0.0024 - val_mean_absolute_error: 0.0309
# Epoch 41/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0021 - mean_absolute_error: 0.0276 - val_loss: 0.0025 - val_mean_absolute_error: 0.0319
# Epoch 42/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0021 - mean_absolute_error: 0.0283 - val_loss: 0.0024 - val_mean_absolute_error: 0.0312
# Epoch 43/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0020 - mean_absolute_error: 0.0276 - val_loss: 0.0025 - val_mean_absolute_error: 0.0327
# Epoch 44/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0020 - mean_absolute_error: 0.0280 - val_loss: 0.0025 - val_mean_absolute_error: 0.0324
# Epoch 45/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0020 - mean_absolute_error: 0.0272 - val_loss: 0.0025 - val_mean_absolute_error: 0.0328
# Epoch 46/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0020 - mean_absolute_error: 0.0274 - val_loss: 0.0024 - val_mean_absolute_error: 0.0313
# Epoch 47/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0020 - mean_absolute_error: 0.0275 - val_loss: 0.0024 - val_mean_absolute_error: 0.0306
# Epoch 48/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0024 - val_mean_absolute_error: 0.0312
# Epoch 49/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0024 - val_mean_absolute_error: 0.0312
# Epoch 50/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0024 - val_mean_absolute_error: 0.0305
# Epoch 51/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0024 - val_mean_absolute_error: 0.0310
# Epoch 52/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0024 - val_mean_absolute_error: 0.0307
# Epoch 53/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0024 - val_mean_absolute_error: 0.0308
# Epoch 54/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0024 - val_mean_absolute_error: 0.0314
# Epoch 55/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0024 - val_mean_absolute_error: 0.0310
# Epoch 56/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0016 - mean_absolute_error: 0.0245 - val_loss: 0.0024 - val_mean_absolute_error: 0.0309
# Epoch 57/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0016 - mean_absolute_error: 0.0246 - val_loss: 0.0024 - val_mean_absolute_error: 0.0309
# Epoch 58/1000
# 5626/5626 [==============================] - 3s 598us/step - loss: 0.0016 - mean_absolute_error: 0.0246 - val_loss: 0.0024 - val_mean_absolute_error: 0.0316
# Epoch 59/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0016 - mean_absolute_error: 0.0248 - val_loss: 0.0024 - val_mean_absolute_error: 0.0311
# Epoch 60/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 0.0016 - mean_absolute_error: 0.0249 - val_loss: 0.0024 - val_mean_absolute_error: 0.0312
# Epoch 61/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0016 - mean_absolute_error: 0.0244 - val_loss: 0.0025 - val_mean_absolute_error: 0.0325
# Epoch 62/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0015 - mean_absolute_error: 0.0241 - val_loss: 0.0024 - val_mean_absolute_error: 0.0307
# Epoch 63/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0015 - mean_absolute_error: 0.0245 - val_loss: 0.0027 - val_mean_absolute_error: 0.0342
# Epoch 64/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0015 - mean_absolute_error: 0.0246 - val_loss: 0.0024 - val_mean_absolute_error: 0.0311
# Epoch 65/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0014 - mean_absolute_error: 0.0234 - val_loss: 0.0024 - val_mean_absolute_error: 0.0308
# Epoch 66/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0014 - mean_absolute_error: 0.0232 - val_loss: 0.0024 - val_mean_absolute_error: 0.0316
# Epoch 67/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0014 - mean_absolute_error: 0.0234 - val_loss: 0.0025 - val_mean_absolute_error: 0.0320
# Epoch 68/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0014 - mean_absolute_error: 0.0241 - val_loss: 0.0024 - val_mean_absolute_error: 0.0314
# Epoch 69/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0014 - mean_absolute_error: 0.0233 - val_loss: 0.0024 - val_mean_absolute_error: 0.0313
# Epoch 70/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0013 - mean_absolute_error: 0.0226 - val_loss: 0.0024 - val_mean_absolute_error: 0.0315
# Epoch 71/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0013 - mean_absolute_error: 0.0224 - val_loss: 0.0024 - val_mean_absolute_error: 0.0315
# Epoch 72/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0013 - mean_absolute_error: 0.0230 - val_loss: 0.0024 - val_mean_absolute_error: 0.0314
# Epoch 73/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0013 - mean_absolute_error: 0.0228 - val_loss: 0.0026 - val_mean_absolute_error: 0.0330
# Epoch 74/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 0.0013 - mean_absolute_error: 0.0228 - val_loss: 0.0024 - val_mean_absolute_error: 0.0320
# Epoch 75/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0012 - mean_absolute_error: 0.0224 - val_loss: 0.0024 - val_mean_absolute_error: 0.0317
# Epoch 76/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0012 - mean_absolute_error: 0.0222 - val_loss: 0.0024 - val_mean_absolute_error: 0.0315
# Epoch 77/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0012 - mean_absolute_error: 0.0217 - val_loss: 0.0024 - val_mean_absolute_error: 0.0313
# Epoch 78/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0011 - mean_absolute_error: 0.0213 - val_loss: 0.0024 - val_mean_absolute_error: 0.0312
# Epoch 79/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 0.0011 - mean_absolute_error: 0.0214 - val_loss: 0.0025 - val_mean_absolute_error: 0.0317
# Epoch 80/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0011 - mean_absolute_error: 0.0218 - val_loss: 0.0025 - val_mean_absolute_error: 0.0319
# Epoch 81/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0011 - mean_absolute_error: 0.0211 - val_loss: 0.0024 - val_mean_absolute_error: 0.0317
# Epoch 82/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0025 - val_mean_absolute_error: 0.0321
# Epoch 83/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 0.0011 - mean_absolute_error: 0.0211 - val_loss: 0.0025 - val_mean_absolute_error: 0.0321
# Epoch 84/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0011 - mean_absolute_error: 0.0215 - val_loss: 0.0025 - val_mean_absolute_error: 0.0319
# Epoch 85/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0011 - mean_absolute_error: 0.0226 - val_loss: 0.0027 - val_mean_absolute_error: 0.0348
# Epoch 86/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0025 - val_mean_absolute_error: 0.0317
# Epoch 87/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 0.0011 - mean_absolute_error: 0.0218 - val_loss: 0.0025 - val_mean_absolute_error: 0.0324
# Epoch 88/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 0.0010 - mean_absolute_error: 0.0209 - val_loss: 0.0025 - val_mean_absolute_error: 0.0322
# Epoch 89/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 9.5658e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0024 - val_mean_absolute_error: 0.0321
# Epoch 90/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 9.0312e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0025 - val_mean_absolute_error: 0.0322
# Epoch 91/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 8.6131e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0025 - val_mean_absolute_error: 0.0320
# Epoch 92/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 8.5962e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0025 - val_mean_absolute_error: 0.0324
# Epoch 93/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 8.7672e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0025 - val_mean_absolute_error: 0.0319
# Epoch 94/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 8.1954e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0024 - val_mean_absolute_error: 0.0318
# Epoch 95/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 7.8806e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0024 - val_mean_absolute_error: 0.0316
# Epoch 96/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 8.1031e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0025 - val_mean_absolute_error: 0.0319
# Epoch 97/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 8.3155e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0026 - val_mean_absolute_error: 0.0328
# Epoch 98/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 7.7142e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0025 - val_mean_absolute_error: 0.0318
# Epoch 99/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 7.2725e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0025 - val_mean_absolute_error: 0.0318
# Epoch 100/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 7.0259e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0025 - val_mean_absolute_error: 0.0318
# Epoch 101/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 6.8409e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0025 - val_mean_absolute_error: 0.0318
# Epoch 102/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 6.9599e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0025 - val_mean_absolute_error: 0.0323
# Epoch 103/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 7.0407e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0026 - val_mean_absolute_error: 0.0326
# Epoch 104/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 6.9444e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0027 - val_mean_absolute_error: 0.0342
# Epoch 105/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 7.2216e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0025 - val_mean_absolute_error: 0.0316
# Epoch 106/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 6.3473e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0025 - val_mean_absolute_error: 0.0317
# Epoch 107/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 6.2712e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0025 - val_mean_absolute_error: 0.0315
# Epoch 108/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 6.0633e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0025 - val_mean_absolute_error: 0.0316
# Epoch 109/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 6.1347e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0025 - val_mean_absolute_error: 0.0318
# Epoch 110/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 5.9709e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0026 - val_mean_absolute_error: 0.0324
# Epoch 111/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 6.0501e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0026 - val_mean_absolute_error: 0.0328
# Epoch 112/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 5.9605e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0026 - val_mean_absolute_error: 0.0319
# Epoch 113/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 5.6395e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0026 - val_mean_absolute_error: 0.0321
# Epoch 114/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 6.2914e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0028 - val_mean_absolute_error: 0.0345
# Epoch 115/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 6.0437e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0026 - val_mean_absolute_error: 0.0322
# Epoch 116/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 5.5303e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0026 - val_mean_absolute_error: 0.0317
# Epoch 117/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 5.3714e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0026 - val_mean_absolute_error: 0.0321
# Epoch 118/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 5.2845e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0026 - val_mean_absolute_error: 0.0315
# Epoch 119/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 5.0078e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0026 - val_mean_absolute_error: 0.0319
# Epoch 120/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 5.1112e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0026 - val_mean_absolute_error: 0.0322
# Epoch 121/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 5.3576e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0026 - val_mean_absolute_error: 0.0321
# Epoch 122/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 5.2070e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0026 - val_mean_absolute_error: 0.0323
# Epoch 123/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 5.2425e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0026 - val_mean_absolute_error: 0.0325
# Epoch 124/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 4.9670e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0026 - val_mean_absolute_error: 0.0321
# Epoch 125/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 4.8328e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0026 - val_mean_absolute_error: 0.0316
# Epoch 126/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 4.7888e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 127/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 5.8004e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0027 - val_mean_absolute_error: 0.0334
# Epoch 128/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 5.4747e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0029 - val_mean_absolute_error: 0.0344
# Epoch 129/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 5.6388e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 130/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 5.0287e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0026 - val_mean_absolute_error: 0.0316
# Epoch 131/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 4.6537e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0026 - val_mean_absolute_error: 0.0317
# Epoch 132/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 4.4346e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0318
# Epoch 133/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 4.3811e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0318
# Epoch 134/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 4.4888e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0026 - val_mean_absolute_error: 0.0318
# Epoch 135/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 4.4823e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0026 - val_mean_absolute_error: 0.0317
# Epoch 136/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 4.3066e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 137/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 4.1327e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0027 - val_mean_absolute_error: 0.0326
# Epoch 138/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 4.3065e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0026 - val_mean_absolute_error: 0.0318
# Epoch 139/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 4.3137e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0320
# Epoch 140/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 4.1736e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0027 - val_mean_absolute_error: 0.0326
# Epoch 141/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 4.3782e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 142/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 4.2206e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0027 - val_mean_absolute_error: 0.0322
# Epoch 143/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 4.3784e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0026 - val_mean_absolute_error: 0.0320
# Epoch 144/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 4.0769e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0026 - val_mean_absolute_error: 0.0321
# Epoch 145/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.8423e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0026 - val_mean_absolute_error: 0.0317
# Epoch 146/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.9150e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 147/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.8863e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0027 - val_mean_absolute_error: 0.0328
# Epoch 148/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.9071e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0026 - val_mean_absolute_error: 0.0318
# Epoch 149/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 3.7594e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 150/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 3.6411e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 151/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 3.7038e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 152/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.7717e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 153/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.5653e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 154/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.5237e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 155/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.6969e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 156/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 4.2136e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 157/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.6923e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0027 - val_mean_absolute_error: 0.0327
# Epoch 158/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.5385e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 159/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.2963e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 160/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.6897e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0027 - val_mean_absolute_error: 0.0318
# Epoch 161/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 3.7956e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0027 - val_mean_absolute_error: 0.0328
# Epoch 162/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 3.5974e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 163/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.2964e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0027 - val_mean_absolute_error: 0.0318
# Epoch 164/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.1289e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 165/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.5523e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 166/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 3.3870e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0027 - val_mean_absolute_error: 0.0322
# Epoch 167/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.1707e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 168/1000
# 5626/5626 [==============================] - 3s 598us/step - loss: 3.2696e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 169/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.9502e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0027 - val_mean_absolute_error: 0.0320
# Epoch 170/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.3182e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0029 - val_mean_absolute_error: 0.0346
# Epoch 171/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.4488e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 172/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.9805e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 173/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.2735e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 174/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.9439e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 175/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.7909e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 176/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.3481e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0027 - val_mean_absolute_error: 0.0322
# Epoch 177/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 3.3178e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0028 - val_mean_absolute_error: 0.0334
# Epoch 178/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 3.3771e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0028 - val_mean_absolute_error: 0.0331
# Epoch 179/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.2908e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0027 - val_mean_absolute_error: 0.0319
# Epoch 180/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 3.0149e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 181/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 3.0170e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0027 - val_mean_absolute_error: 0.0330
# Epoch 182/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.1088e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0027 - val_mean_absolute_error: 0.0327
# Epoch 183/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 3.2548e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 184/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 3.0946e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 185/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 2.7210e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 186/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.6742e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 187/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 2.8098e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 188/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.8021e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0028 - val_mean_absolute_error: 0.0326
# Epoch 189/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.7198e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0027 - val_mean_absolute_error: 0.0326
# Epoch 190/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.6569e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 191/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.5749e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0027 - val_mean_absolute_error: 0.0321
# Epoch 192/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.5743e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 193/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.6552e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 194/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.4135e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 195/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 2.3822e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 196/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.6062e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 197/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.4306e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 198/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.8036e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 199/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 2.5033e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 200/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.5493e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 201/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.4865e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 202/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.3324e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0027 - val_mean_absolute_error: 0.0323
# Epoch 203/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.6258e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 204/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.6455e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 205/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 2.4473e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 206/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.6395e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 207/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 2.4552e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 208/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.3876e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0028 - val_mean_absolute_error: 0.0329
# Epoch 209/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.3070e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 210/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.4100e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0028 - val_mean_absolute_error: 0.0333
# Epoch 211/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.4551e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 212/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.2763e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 213/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.8704e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0028 - val_mean_absolute_error: 0.0332
# Epoch 214/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.8579e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0028 - val_mean_absolute_error: 0.0332
# Epoch 215/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.9991e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 216/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.7411e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 217/1000
# 5626/5626 [==============================] - 3s 597us/step - loss: 2.4533e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 218/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.3093e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0027 - val_mean_absolute_error: 0.0329
# Epoch 219/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.2579e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0027 - val_mean_absolute_error: 0.0326
# Epoch 220/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 2.1079e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0027 - val_mean_absolute_error: 0.0322
# Epoch 221/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1749e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 222/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1366e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 223/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.3658e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0327
# Epoch 224/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1535e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 225/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.0205e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0028 - val_mean_absolute_error: 0.0332
# Epoch 226/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.2166e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 227/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.5712e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0028 - val_mean_absolute_error: 0.0331
# Epoch 228/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.5503e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0028 - val_mean_absolute_error: 0.0333
# Epoch 229/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 2.5333e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 230/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1148e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 231/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.0862e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0027 - val_mean_absolute_error: 0.0325
# Epoch 232/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 2.3779e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 233/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 2.0979e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0027 - val_mean_absolute_error: 0.0329
# Epoch 234/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1076e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 235/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.1369e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 236/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1207e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 237/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.9482e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0027 - val_mean_absolute_error: 0.0328
# Epoch 238/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.0080e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0029 - val_mean_absolute_error: 0.0335
# Epoch 239/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.3193e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0028 - val_mean_absolute_error: 0.0338
# Epoch 240/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.2904e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
# Epoch 241/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.8940e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 242/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 1.9640e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 243/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.9973e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 244/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.9556e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 245/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.8895e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0028 - val_mean_absolute_error: 0.0326
# Epoch 246/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.0474e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0028 - val_mean_absolute_error: 0.0329
# Epoch 247/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.9841e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0028 - val_mean_absolute_error: 0.0335
# Epoch 248/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 2.3152e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0028 - val_mean_absolute_error: 0.0331
# Epoch 249/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.0787e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0329
# Epoch 250/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.9956e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0028 - val_mean_absolute_error: 0.0329
# Epoch 251/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.8806e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0028 - val_mean_absolute_error: 0.0334
# Epoch 252/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.9633e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0028 - val_mean_absolute_error: 0.0334
# Epoch 253/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.0226e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 254/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 1.9029e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 255/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.0750e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0340
# Epoch 256/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.1672e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 257/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.1103e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0332
# Epoch 258/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 2.1197e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0331
# Epoch 259/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 2.0792e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0028 - val_mean_absolute_error: 0.0332
# Epoch 260/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 2.0351e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 261/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.1851e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0028 - val_mean_absolute_error: 0.0334
# Epoch 262/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.7673e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 263/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.9595e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0028 - val_mean_absolute_error: 0.0340
# Epoch 264/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.9282e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0028 - val_mean_absolute_error: 0.0329
# Epoch 265/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.8976e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0029 - val_mean_absolute_error: 0.0336
# Epoch 266/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.0861e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0028 - val_mean_absolute_error: 0.0335
# Epoch 267/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.7594e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0028 - val_mean_absolute_error: 0.0327
# Epoch 268/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.6558e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0028 - val_mean_absolute_error: 0.0334
# Epoch 269/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 2.1821e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0028 - val_mean_absolute_error: 0.0333
# Epoch 270/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 2.2349e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0331
# Epoch 271/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.7689e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0028 - val_mean_absolute_error: 0.0329
# Epoch 272/1000
# 5626/5626 [==============================] - 3s 596us/step - loss: 1.8298e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0028 - val_mean_absolute_error: 0.0326
# Epoch 273/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.5845e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0028 - val_mean_absolute_error: 0.0330
# Epoch 274/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.5442e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0028 - val_mean_absolute_error: 0.0328
# Epoch 275/1000
# ...
# Epoch 911/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1076e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 912/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0733e-04 - mean_absolute_error: 0.0036 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 913/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1268e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0026 - val_mean_absolute_error: 0.0309
# Epoch 914/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1408e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 915/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1221e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 916/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0539e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0026 - val_mean_absolute_error: 0.0311
# Epoch 917/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.0516e-04 - mean_absolute_error: 0.0035 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 918/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0949e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0025 - val_mean_absolute_error: 0.0309
# Epoch 919/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1362e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0026 - val_mean_absolute_error: 0.0309
# Epoch 920/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1212e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0309
# Epoch 921/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1550e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0026 - val_mean_absolute_error: 0.0310
# Epoch 922/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1727e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 923/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0510e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 924/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0808e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0026 - val_mean_absolute_error: 0.0308
# Epoch 925/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1061e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0026 - val_mean_absolute_error: 0.0309
# Epoch 926/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1593e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 927/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1557e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0026 - val_mean_absolute_error: 0.0311
# Epoch 928/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.2469e-04 - mean_absolute_error: 0.0050 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 929/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.1782e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 930/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1208e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 931/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.1237e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 932/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.0980e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 933/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0898e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 934/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0452e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 935/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0877e-04 - mean_absolute_error: 0.0039 - val_loss: 0.0026 - val_mean_absolute_error: 0.0312
# Epoch 936/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1209e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0026 - val_mean_absolute_error: 0.0309
# Epoch 937/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1950e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 938/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1351e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 939/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1300e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 940/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1913e-04 - mean_absolute_error: 0.0050 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 941/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1821e-04 - mean_absolute_error: 0.0046 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 942/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1419e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0305
# Epoch 943/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1190e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 944/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1467e-04 - mean_absolute_error: 0.0046 - val_loss: 0.0026 - val_mean_absolute_error: 0.0307
# Epoch 945/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1452e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 946/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1193e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 947/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0910e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 948/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0476e-04 - mean_absolute_error: 0.0039 - val_loss: 0.0025 - val_mean_absolute_error: 0.0309
# Epoch 949/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1302e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 950/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1604e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 951/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1077e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0026 - val_mean_absolute_error: 0.0309
# Epoch 952/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1454e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0026 - val_mean_absolute_error: 0.0309
# Epoch 953/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1969e-04 - mean_absolute_error: 0.0047 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 954/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.2039e-04 - mean_absolute_error: 0.0049 - val_loss: 0.0025 - val_mean_absolute_error: 0.0309
# Epoch 955/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1726e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 956/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.1056e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0305
# Epoch 957/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1163e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 958/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1188e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 959/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0763e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 960/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1136e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0305
# Epoch 961/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.2198e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 962/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1356e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0026 - val_mean_absolute_error: 0.0308
# Epoch 963/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0977e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 964/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0888e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 965/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0347e-04 - mean_absolute_error: 0.0035 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 966/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0543e-04 - mean_absolute_error: 0.0035 - val_loss: 0.0025 - val_mean_absolute_error: 0.0302
# Epoch 967/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0698e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0305
# Epoch 968/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0741e-04 - mean_absolute_error: 0.0036 - val_loss: 0.0025 - val_mean_absolute_error: 0.0308
# Epoch 969/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0825e-04 - mean_absolute_error: 0.0039 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 970/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0861e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 971/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0509e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0303
# Epoch 972/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1404e-04 - mean_absolute_error: 0.0041 - val_loss: 0.0025 - val_mean_absolute_error: 0.0305
# Epoch 973/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.1781e-04 - mean_absolute_error: 0.0048 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
# Epoch 974/1000
# 5626/5626 [==============================] - 3s 594us/step - loss: 1.1662e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 975/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.1429e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 976/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1080e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0303
# Epoch 977/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1197e-04 - mean_absolute_error: 0.0039 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 978/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0863e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0301
# Epoch 979/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.0960e-04 - mean_absolute_error: 0.0039 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 980/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1668e-04 - mean_absolute_error: 0.0042 - val_loss: 0.0025 - val_mean_absolute_error: 0.0305
# Epoch 981/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0302e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0303
# Epoch 982/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0662e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 983/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.0681e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 984/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0782e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 985/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0995e-04 - mean_absolute_error: 0.0037 - val_loss: 0.0025 - val_mean_absolute_error: 0.0301
# Epoch 986/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1060e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0301
# Epoch 987/1000
# 5626/5626 [==============================] - 3s 595us/step - loss: 1.0902e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0302
# Epoch 988/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1809e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0303
# Epoch 989/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.1557e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0301
# Epoch 990/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1948e-04 - mean_absolute_error: 0.0047 - val_loss: 0.0025 - val_mean_absolute_error: 0.0303
# Epoch 991/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.1869e-04 - mean_absolute_error: 0.0044 - val_loss: 0.0025 - val_mean_absolute_error: 0.0300
# Epoch 992/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1885e-04 - mean_absolute_error: 0.0046 - val_loss: 0.0025 - val_mean_absolute_error: 0.0302
# Epoch 993/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1212e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 994/1000
# 5626/5626 [==============================] - 3s 591us/step - loss: 1.1547e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0301
# Epoch 995/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.0752e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0304
# Epoch 996/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0691e-04 - mean_absolute_error: 0.0040 - val_loss: 0.0025 - val_mean_absolute_error: 0.0302
# Epoch 997/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.0852e-04 - mean_absolute_error: 0.0038 - val_loss: 0.0025 - val_mean_absolute_error: 0.0303
# Epoch 998/1000
# 5626/5626 [==============================] - 3s 593us/step - loss: 1.1291e-04 - mean_absolute_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0301
# Epoch 999/1000
# 5626/5626 [==============================] - 3s 592us/step - loss: 1.1590e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
# Epoch 1000/1000
# 5626/5626 [==============================] - 3s 590us/step - loss: 1.1521e-04 - mean_absolute_error: 0.0045 - val_loss: 0.0024 - val_mean_absolute_error: 0.0300

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_1000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_2000.h5')

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_2000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_3000.h5')

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_3000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_4000.h5')

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_4000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_5000.h5')
