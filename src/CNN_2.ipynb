# %% [markdown]
# ### Neural Network Architecture
# * (3x3) | 32
# * (3x3) | 64
# * Dense | 128
# * Dense | 128
# * Dense | 4
#
# ### Training Set
# * 7033 : Eye Centers
# * 7033 : Eye Centers; Data Augmented (LR Flipped)

# %%
# !ls
# Out:
# datalab  drive

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install -q keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential, load_model
from keras.layers import BatchNormalization, Conv2D, Activation, MaxPooling2D, Dense, Flatten, Dropout, GlobalAveragePooling2D
from keras import optimizers
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("drive/facial-landmark-detection/training.csv")

# %%
df.shape
# Out:
# (7049, 31)

# %%
df2 = df.iloc[:,[0,1,2,3,30]]
df2 = df2.dropna()
df2.shape
# Out:
# (7033, 5)

# %%
imageStringList = []
imageStringList.extend(df2.loc[:,"Image"])

# converting the strings to numpy arrays
print "[INFO] Converting string enteries to images"
imageList = []
index=0
for s in imageStringList:
	imageList.append(np.array([int (e) for e in s.split(" ")]).reshape((96,96)))
	index = index + 1
	if index%500 == 0 :
		print str(index) + " images converted"
# Out:
# [INFO] Converting string enteries to images
# 500 images converted
# 1000 images converted
# 1500 images converted
# 2000 images converted
# 2500 images converted
# 3000 images converted
# 3500 images converted
# 4000 images converted
# 4500 images converted
# 5000 images converted
# 5500 images converted
# 6000 images converted
# 6500 images converted
# 7000 images converted

# %%
def invert(X1):
    xTemp = np.copy(X1)
    xTemp2 = np.copy(xTemp)
    
    for i in range(0,len(X1)) :
        xTemp2[i,:,:,0] = np.copy(np.fliplr(xTemp[i,:,:,0]))
    
    return xTemp2

def swap(Y):
    YTemp = np.copy(Y)

    col0 = np.copy(Y[:,0])
    col2 = np.copy(Y[:,2])
    YTemp[:,0] = col2
    YTemp[:,2] = col0
    
    col1 = np.copy(Y[:,1])
    col3 = np.copy(Y[:,3])
    YTemp[:,1] = col3
    YTemp[:,3] = col1
    
    return YTemp
  
def generate(modelDict) :
    # plotting the loss and metric for the model
    ax1 = plt.subplot(2,1,1)
    plt.plot(modelDict['mean_absolute_error'], linestyle='--', marker='o', color='b')
    plt.plot(modelDict['val_mean_absolute_error'], linestyle='--', marker='o', color='g')
    level1 = modelDict['mean_absolute_error'][0]
    level2 = modelDict['mean_absolute_error'][0] - 0.01
    i = 0
    for e in modelDict['mean_absolute_error']:
        if i%100==99 :
            e = round(e,4)
            ax1.annotate('('+str(i)+','+str(e)+')', xy=(i,level1), textcoords='data',color='b')
        i = i+1
    i = 0
    for e in modelDict['val_mean_absolute_error']:
        if i%100==99 :
            e = round(e,4)
            ax1.annotate('('+str(i)+','+str(e)+')', xy=(i,level2), textcoords='data',color='g')
        i = i+1
    plt.title('MAE | mean absolute error')
    plt.ylabel('mae')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower left')

    ax2 = plt.subplot(2,1,2)
    plt.plot(modelDict['loss'], linestyle='--', marker='o', color='b')
    plt.plot(modelDict['val_loss'], linestyle='--', marker='o', color='g')
    level1 = modelDict['loss'][0]
    level2 = modelDict['loss'][0] - 0.01
    i = 0
    for e in modelDict['loss']:
        if i%100==99 :
            e = round(e,4)
            ax2.annotate('('+str(i)+','+str(e)+')', xy=(i,level1), textcoords='data',color='b')
        i = i+1
    i = 0
    for e in modelDict['val_loss']:
        if i%100==99 :
            e = round(e,4)
            ax2.annotate('('+str(i)+','+str(e)+')', xy=(i,level2), textcoords='data',color='g')
        i = i+1
    plt.title('MSE | mean squared error')
    plt.ylabel('mse')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower left')

    # exporting the plot
    plt.tight_layout()
    fig = plt.gcf()
    fig.set_size_inches((16,9), forward=False)
    plt.show()

# %%
# preparing the training data
# input
X_temp = np.stack(imageList,axis=0)
X1 = X_temp.astype(np.float32)[:,:,:,np.newaxis] 				    # X1.shape = (7033,96,96,1)
X2 = invert(X1)                                             # X2.shape = (7033,96,96,1)
X = np.concatenate((X1,X2),axis=0)

# output
Y1 = np.stack(df2.iloc[:,range(0,4)].values,axis=0) 	      # Y1.shape(7033,4)
Y2 = swap(Y1)                                               # Y2.shape(7033,4)
Y = np.concatenate((Y1,Y2),axis=0)

# scaling input range to [0,1] from [0,255]
X = X.astype(np.float32)
X = X/255.0

# scaling target values to [-1,1] from [0,95]
Y = Y.astype(np.float32)
Y = (Y - 48.0)/48.0

# %%
X.shape
# Out:
# (14066, 96, 96, 1)

# %%
Y.shape
# Out:
# (14066, 4)

# %%
X, Y = shuffle(X, Y, random_state=42)  # shuffle data

# %%
# creating the ann model
model = Sequential()

model.add(BatchNormalization(input_shape=(96,96,1)))
# (96,96,1)

model.add(Conv2D(filters=32, kernel_size=(3,3), strides=(1,1)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# (47,47,32)

model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# (22,22,64)

model.add(Flatten())

model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(4))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 94, 94, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 94, 94, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 45, 45, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 4,000,904
# Trainable params: 4,000,902
# Non-trainable params: 2
# _________________________________________________________________

# %%
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_2_1000.h5')
# Out:
# [INFO] Training
# Train on 11252 samples, validate on 2814 samples
# Epoch 1/1000
# 11252/11252 [==============================] - 7s 602us/step - loss: 0.0085 - mean_absolute_error: 0.0345 - val_loss: 0.0519 - val_mean_absolute_error: 0.1027
# Epoch 2/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0070 - mean_absolute_error: 0.0366 - val_loss: 0.0490 - val_mean_absolute_error: 0.1021
# Epoch 3/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 0.0047 - mean_absolute_error: 0.0317 - val_loss: 0.0511 - val_mean_absolute_error: 0.1043
# Epoch 4/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 0.0033 - mean_absolute_error: 0.0288 - val_loss: 0.0495 - val_mean_absolute_error: 0.0998
# Epoch 5/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 0.0022 - mean_absolute_error: 0.0244 - val_loss: 0.0491 - val_mean_absolute_error: 0.0990
# Epoch 6/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0015 - mean_absolute_error: 0.0213 - val_loss: 0.0486 - val_mean_absolute_error: 0.0969
# Epoch 7/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0011 - mean_absolute_error: 0.0192 - val_loss: 0.0482 - val_mean_absolute_error: 0.0962
# Epoch 8/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 8.3076e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0479 - val_mean_absolute_error: 0.0954
# Epoch 9/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 6.1375e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0487 - val_mean_absolute_error: 0.0958
# Epoch 10/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 5.1584e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0484 - val_mean_absolute_error: 0.0953
# Epoch 11/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 4.5355e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0483 - val_mean_absolute_error: 0.0952
# Epoch 12/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 3.9909e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0482 - val_mean_absolute_error: 0.0949
# Epoch 13/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 3.6265e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0484 - val_mean_absolute_error: 0.0951
# Epoch 14/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 3.3426e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0485 - val_mean_absolute_error: 0.0952
# Epoch 15/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 3.1358e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0487 - val_mean_absolute_error: 0.0954
# Epoch 16/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 2.9851e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0484 - val_mean_absolute_error: 0.0948
# Epoch 17/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.7390e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0480 - val_mean_absolute_error: 0.0947
# Epoch 18/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.5430e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0484 - val_mean_absolute_error: 0.0948
# Epoch 19/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 2.4789e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0481 - val_mean_absolute_error: 0.0946
# Epoch 20/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 2.3444e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0483 - val_mean_absolute_error: 0.0947
# Epoch 21/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.4115e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0482 - val_mean_absolute_error: 0.0947
# Epoch 22/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.2115e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0485 - val_mean_absolute_error: 0.0949
# Epoch 23/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 2.2001e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0483 - val_mean_absolute_error: 0.0947
# Epoch 24/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.0538e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0480 - val_mean_absolute_error: 0.0945
# Epoch 25/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.9738e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0482 - val_mean_absolute_error: 0.0947
# Epoch 26/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.9872e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0485 - val_mean_absolute_error: 0.0950
# Epoch 27/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.9044e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0482 - val_mean_absolute_error: 0.0949
# Epoch 28/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.8580e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0481 - val_mean_absolute_error: 0.0946
# Epoch 29/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.8447e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0478 - val_mean_absolute_error: 0.0945
# Epoch 30/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.8947e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0477 - val_mean_absolute_error: 0.0943
# Epoch 31/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.7925e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0478 - val_mean_absolute_error: 0.0944
# Epoch 32/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.7181e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0477 - val_mean_absolute_error: 0.0944
# Epoch 33/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.7502e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0476 - val_mean_absolute_error: 0.0942
# Epoch 34/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.6739e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0476 - val_mean_absolute_error: 0.0943
# Epoch 35/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.6001e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0476 - val_mean_absolute_error: 0.0944
# Epoch 36/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.8102e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0485 - val_mean_absolute_error: 0.0952
# Epoch 37/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.6521e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0484 - val_mean_absolute_error: 0.0951
# Epoch 38/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.5662e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0483 - val_mean_absolute_error: 0.0949
# Epoch 39/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.7387e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0477 - val_mean_absolute_error: 0.0943
# Epoch 40/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.7110e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0479 - val_mean_absolute_error: 0.0945
# Epoch 41/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.5844e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0479 - val_mean_absolute_error: 0.0945
# Epoch 42/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.4937e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0478 - val_mean_absolute_error: 0.0945
# Epoch 43/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.4932e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0479 - val_mean_absolute_error: 0.0949
# Epoch 44/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.5524e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0484 - val_mean_absolute_error: 0.0954
# Epoch 45/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.5448e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0487 - val_mean_absolute_error: 0.0953
# Epoch 46/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.5453e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0486 - val_mean_absolute_error: 0.0955
# Epoch 47/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.4522e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0489 - val_mean_absolute_error: 0.0955
# Epoch 48/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.4200e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0484 - val_mean_absolute_error: 0.0952
# Epoch 49/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.5334e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0494 - val_mean_absolute_error: 0.0963
# Epoch 50/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.4218e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0485 - val_mean_absolute_error: 0.0954
# Epoch 51/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.3968e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0484 - val_mean_absolute_error: 0.0953
# Epoch 52/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.4664e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0483 - val_mean_absolute_error: 0.0952
# Epoch 53/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.4506e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0489 - val_mean_absolute_error: 0.0960
# Epoch 54/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.3365e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0488 - val_mean_absolute_error: 0.0959
# Epoch 55/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.3921e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0485 - val_mean_absolute_error: 0.0956
# Epoch 56/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.4717e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0482 - val_mean_absolute_error: 0.0952
# Epoch 57/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.3597e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0481 - val_mean_absolute_error: 0.0950
# Epoch 58/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.3615e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0482 - val_mean_absolute_error: 0.0953
# Epoch 59/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.3298e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0482 - val_mean_absolute_error: 0.0953
# Epoch 60/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2699e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0482 - val_mean_absolute_error: 0.0951
# Epoch 61/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.2743e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0486 - val_mean_absolute_error: 0.0957
# Epoch 62/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2491e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0484 - val_mean_absolute_error: 0.0955
# Epoch 63/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2293e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0486 - val_mean_absolute_error: 0.0956
# Epoch 64/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2227e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0484 - val_mean_absolute_error: 0.0954
# Epoch 65/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2205e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0485 - val_mean_absolute_error: 0.0955
# Epoch 66/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2117e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0483 - val_mean_absolute_error: 0.0952
# Epoch 67/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2112e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0484 - val_mean_absolute_error: 0.0954
# Epoch 68/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1486e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0483 - val_mean_absolute_error: 0.0952
# Epoch 69/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1935e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0484 - val_mean_absolute_error: 0.0952
# Epoch 70/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.1274e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0483 - val_mean_absolute_error: 0.0955
# Epoch 71/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1387e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0483 - val_mean_absolute_error: 0.0954
# Epoch 72/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2044e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0487 - val_mean_absolute_error: 0.0958
# Epoch 73/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.1878e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0480 - val_mean_absolute_error: 0.0950
# Epoch 74/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2236e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0482 - val_mean_absolute_error: 0.0954
# Epoch 75/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2416e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0483 - val_mean_absolute_error: 0.0953
# Epoch 76/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2655e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0484 - val_mean_absolute_error: 0.0957
# Epoch 77/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2449e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0483 - val_mean_absolute_error: 0.0954
# Epoch 78/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2784e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0485 - val_mean_absolute_error: 0.0956
# Epoch 79/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.1741e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0485 - val_mean_absolute_error: 0.0956
# Epoch 80/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1415e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0484 - val_mean_absolute_error: 0.0957
# Epoch 81/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1997e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0482 - val_mean_absolute_error: 0.0951
# Epoch 82/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1369e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0483 - val_mean_absolute_error: 0.0954
# Epoch 83/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1838e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0484 - val_mean_absolute_error: 0.0957
# Epoch 84/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.2911e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0482 - val_mean_absolute_error: 0.0955
# Epoch 85/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.3255e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0481 - val_mean_absolute_error: 0.0953
# Epoch 86/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2198e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0484 - val_mean_absolute_error: 0.0956
# Epoch 87/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2062e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0484 - val_mean_absolute_error: 0.0958
# Epoch 88/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2407e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0483 - val_mean_absolute_error: 0.0955
# Epoch 89/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.1412e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0484 - val_mean_absolute_error: 0.0955
# Epoch 90/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0699e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0482 - val_mean_absolute_error: 0.0953
# Epoch 91/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1265e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0487 - val_mean_absolute_error: 0.0959
# Epoch 92/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1604e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0484 - val_mean_absolute_error: 0.0957
# Epoch 93/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1624e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0484 - val_mean_absolute_error: 0.0958
# Epoch 94/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2743e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0481 - val_mean_absolute_error: 0.0955
# Epoch 95/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.3822e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0485 - val_mean_absolute_error: 0.0957
# Epoch 96/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.4193e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0484 - val_mean_absolute_error: 0.0960
# Epoch 97/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.3049e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0482 - val_mean_absolute_error: 0.0956
# Epoch 98/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.1755e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0486 - val_mean_absolute_error: 0.0960
# Epoch 99/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0585e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0479 - val_mean_absolute_error: 0.0953
# Epoch 100/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0107e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0484 - val_mean_absolute_error: 0.0959
# Epoch 101/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0495e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0485 - val_mean_absolute_error: 0.0959
# Epoch 102/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0354e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0485 - val_mean_absolute_error: 0.0960
# Epoch 103/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0760e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0483 - val_mean_absolute_error: 0.0957
# Epoch 104/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.0898e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0487 - val_mean_absolute_error: 0.0961
# Epoch 105/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1431e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0484 - val_mean_absolute_error: 0.0958
# Epoch 106/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0665e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0484 - val_mean_absolute_error: 0.0958
# Epoch 107/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0116e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0479 - val_mean_absolute_error: 0.0956
# Epoch 108/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0276e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0487 - val_mean_absolute_error: 0.0962
# Epoch 109/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0144e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0484 - val_mean_absolute_error: 0.0959
# Epoch 110/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0315e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0484 - val_mean_absolute_error: 0.0960
# Epoch 111/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0918e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0484 - val_mean_absolute_error: 0.0961
# Epoch 112/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1809e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0481 - val_mean_absolute_error: 0.0956
# Epoch 113/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0786e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0485 - val_mean_absolute_error: 0.0960
# Epoch 114/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0404e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0478 - val_mean_absolute_error: 0.0955
# Epoch 115/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0864e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0482 - val_mean_absolute_error: 0.0955
# Epoch 116/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0415e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0483 - val_mean_absolute_error: 0.0960
# Epoch 117/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1018e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0482 - val_mean_absolute_error: 0.0958
# Epoch 118/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0627e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0483 - val_mean_absolute_error: 0.0958
# Epoch 119/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0462e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0485 - val_mean_absolute_error: 0.0961
# Epoch 120/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0543e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0483 - val_mean_absolute_error: 0.0959
# Epoch 121/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0152e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0486 - val_mean_absolute_error: 0.0962
# Epoch 122/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0704e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0480 - val_mean_absolute_error: 0.0953
# Epoch 123/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1096e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0478 - val_mean_absolute_error: 0.0954
# Epoch 124/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1292e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0480 - val_mean_absolute_error: 0.0954
# Epoch 125/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0796e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0478 - val_mean_absolute_error: 0.0952
# Epoch 126/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0506e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0482 - val_mean_absolute_error: 0.0959
# Epoch 127/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 9.8903e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0481 - val_mean_absolute_error: 0.0956
# Epoch 128/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0065e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0482 - val_mean_absolute_error: 0.0957
# Epoch 129/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.9323e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0483 - val_mean_absolute_error: 0.0958
# Epoch 130/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0049e-04 - mean_absolute_error: 0.0055 - val_loss: 0.0484 - val_mean_absolute_error: 0.0958
# Epoch 131/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.5403e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0480 - val_mean_absolute_error: 0.0955
# Epoch 132/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0519e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0488 - val_mean_absolute_error: 0.0966
# Epoch 133/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0439e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0484 - val_mean_absolute_error: 0.0960
# Epoch 134/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0165e-04 - mean_absolute_error: 0.0055 - val_loss: 0.0484 - val_mean_absolute_error: 0.0963
# Epoch 135/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0662e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0483 - val_mean_absolute_error: 0.0957
# Epoch 136/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0468e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0485 - val_mean_absolute_error: 0.0960
# Epoch 137/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.0114e-04 - mean_absolute_error: 0.0054 - val_loss: 0.0485 - val_mean_absolute_error: 0.0959
# Epoch 138/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0482e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0481 - val_mean_absolute_error: 0.0956
# Epoch 139/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0533e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0488 - val_mean_absolute_error: 0.0962
# Epoch 140/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0425e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0487 - val_mean_absolute_error: 0.0965
# Epoch 141/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0353e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0484 - val_mean_absolute_error: 0.0961
# Epoch 142/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0000e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0486 - val_mean_absolute_error: 0.0963
# Epoch 143/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.8349e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0482 - val_mean_absolute_error: 0.0961
# Epoch 144/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.9393e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0486 - val_mean_absolute_error: 0.0962
# Epoch 145/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.4339e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0483 - val_mean_absolute_error: 0.0963
# Epoch 146/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.3961e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0484 - val_mean_absolute_error: 0.0961
# Epoch 147/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.3777e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0487 - val_mean_absolute_error: 0.0964
# Epoch 148/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0330e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0485 - val_mean_absolute_error: 0.0959
# Epoch 149/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0142e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0489 - val_mean_absolute_error: 0.0964
# Epoch 150/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0498e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0487 - val_mean_absolute_error: 0.0968
# Epoch 151/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0388e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0483 - val_mean_absolute_error: 0.0961
# Epoch 152/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0395e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0484 - val_mean_absolute_error: 0.0962
# Epoch 153/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0314e-04 - mean_absolute_error: 0.0057 - val_loss: 0.0486 - val_mean_absolute_error: 0.0962
# Epoch 154/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0144e-04 - mean_absolute_error: 0.0055 - val_loss: 0.0485 - val_mean_absolute_error: 0.0962
# Epoch 155/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.3842e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0484 - val_mean_absolute_error: 0.0967
# Epoch 156/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.1601e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0493 - val_mean_absolute_error: 0.0971
# Epoch 157/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 6.0805e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0513 - val_mean_absolute_error: 0.1028
# Epoch 158/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0034 - mean_absolute_error: 0.0277 - val_loss: 0.0525 - val_mean_absolute_error: 0.1087
# Epoch 159/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0056 - mean_absolute_error: 0.0359 - val_loss: 0.0525 - val_mean_absolute_error: 0.1091
# Epoch 160/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 0.0055 - mean_absolute_error: 0.0373 - val_loss: 0.0563 - val_mean_absolute_error: 0.1140
# Epoch 161/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 0.0037 - mean_absolute_error: 0.0319 - val_loss: 0.0519 - val_mean_absolute_error: 0.1063
# Epoch 162/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0022 - mean_absolute_error: 0.0261 - val_loss: 0.0519 - val_mean_absolute_error: 0.1058
# Epoch 163/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 0.0013 - mean_absolute_error: 0.0223 - val_loss: 0.0497 - val_mean_absolute_error: 0.1013
# Epoch 164/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.5597e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0508 - val_mean_absolute_error: 0.1027
# Epoch 165/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 5.6366e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0502 - val_mean_absolute_error: 0.1011
# Epoch 166/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 4.2829e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0503 - val_mean_absolute_error: 0.1002
# Epoch 167/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 3.4607e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0502 - val_mean_absolute_error: 0.1003
# Epoch 168/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 3.1608e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0512 - val_mean_absolute_error: 0.1014
# Epoch 169/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 2.6436e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0504 - val_mean_absolute_error: 0.1001
# Epoch 170/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 2.3009e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0505 - val_mean_absolute_error: 0.1002
# Epoch 171/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 2.1325e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0504 - val_mean_absolute_error: 0.0999
# Epoch 172/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 2.0541e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0500 - val_mean_absolute_error: 0.0996
# Epoch 173/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.8740e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0499 - val_mean_absolute_error: 0.0995
# Epoch 174/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.8414e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0501 - val_mean_absolute_error: 0.0996
# Epoch 175/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.7184e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0502 - val_mean_absolute_error: 0.0995
# Epoch 176/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.7112e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0503 - val_mean_absolute_error: 0.0998
# Epoch 177/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.6351e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0500 - val_mean_absolute_error: 0.0996
# Epoch 178/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.5829e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0499 - val_mean_absolute_error: 0.0994
# Epoch 179/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.5063e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0507 - val_mean_absolute_error: 0.1004
# Epoch 180/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.6683e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0508 - val_mean_absolute_error: 0.1005
# Epoch 181/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.5069e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0502 - val_mean_absolute_error: 0.0997
# Epoch 182/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.3921e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0500 - val_mean_absolute_error: 0.0997
# Epoch 183/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.3495e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0502 - val_mean_absolute_error: 0.0996
# Epoch 184/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.3241e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0500 - val_mean_absolute_error: 0.0994
# Epoch 185/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.2526e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0501 - val_mean_absolute_error: 0.0996
# Epoch 186/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.3268e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0500 - val_mean_absolute_error: 0.0994
# Epoch 187/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.2070e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 188/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.2273e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0500 - val_mean_absolute_error: 0.0995
# Epoch 189/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1955e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0501 - val_mean_absolute_error: 0.0995
# Epoch 190/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.1768e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0501 - val_mean_absolute_error: 0.0996
# Epoch 191/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1833e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0502 - val_mean_absolute_error: 0.0995
# Epoch 192/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1283e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0502 - val_mean_absolute_error: 0.0997
# Epoch 193/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1950e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0499 - val_mean_absolute_error: 0.0991
# Epoch 194/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1504e-04 - mean_absolute_error: 0.0066 - val_loss: 0.0499 - val_mean_absolute_error: 0.0994
# Epoch 195/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.1469e-04 - mean_absolute_error: 0.0065 - val_loss: 0.0498 - val_mean_absolute_error: 0.0990
# Epoch 196/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 1.1034e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 197/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0756e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0496 - val_mean_absolute_error: 0.0989
# Epoch 198/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0506e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0501 - val_mean_absolute_error: 0.0994
# Epoch 199/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0614e-04 - mean_absolute_error: 0.0062 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 200/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.1057e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0502 - val_mean_absolute_error: 0.0993
# Epoch 201/1000
# 11252/11252 [==============================] - 7s 593us/step - loss: 1.1077e-04 - mean_absolute_error: 0.0064 - val_loss: 0.0499 - val_mean_absolute_error: 0.0992
# Epoch 202/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.1018e-04 - mean_absolute_error: 0.0063 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 203/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0381e-04 - mean_absolute_error: 0.0061 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 204/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.7623e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 205/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.8424e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0500 - val_mean_absolute_error: 0.0993
# Epoch 206/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.3867e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0498 - val_mean_absolute_error: 0.0992
# Epoch 207/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.9321e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0498 - val_mean_absolute_error: 0.0991
# Epoch 208/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 1.0238e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0499 - val_mean_absolute_error: 0.0994
# Epoch 209/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.9533e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0498 - val_mean_absolute_error: 0.0994
# Epoch 210/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.9424e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 211/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0180e-04 - mean_absolute_error: 0.0059 - val_loss: 0.0497 - val_mean_absolute_error: 0.0990
# Epoch 212/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.5137e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0499 - val_mean_absolute_error: 0.0992
# Epoch 213/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.2324e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0499 - val_mean_absolute_error: 0.0992
# Epoch 214/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.1722e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0499 - val_mean_absolute_error: 0.0994
# Epoch 215/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.4181e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0497 - val_mean_absolute_error: 0.0991
# Epoch 216/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.3460e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0500 - val_mean_absolute_error: 0.0994
# Epoch 217/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.6182e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 218/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0069e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0497 - val_mean_absolute_error: 0.0991
# Epoch 219/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.4573e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0499 - val_mean_absolute_error: 0.0992
# Epoch 220/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.5693e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 221/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.3494e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 222/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.2796e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0499 - val_mean_absolute_error: 0.0992
# Epoch 223/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.3428e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0501 - val_mean_absolute_error: 0.0995
# Epoch 224/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.7630e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0502 - val_mean_absolute_error: 0.0994
# Epoch 225/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.5100e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0502 - val_mean_absolute_error: 0.0994
# Epoch 226/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.1945e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0499 - val_mean_absolute_error: 0.0994
# Epoch 227/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.3748e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0500 - val_mean_absolute_error: 0.0993
# Epoch 228/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.8663e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0498 - val_mean_absolute_error: 0.0994
# Epoch 229/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.0930e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0500 - val_mean_absolute_error: 0.0994
# Epoch 230/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 8.8676e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 231/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.1322e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0499 - val_mean_absolute_error: 0.0994
# Epoch 232/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 8.9468e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 233/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 8.9100e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0500 - val_mean_absolute_error: 0.0993
# Epoch 234/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.7788e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0499 - val_mean_absolute_error: 0.0992
# Epoch 235/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 8.9892e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 236/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.5574e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0501 - val_mean_absolute_error: 0.0993
# Epoch 237/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.4439e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0498 - val_mean_absolute_error: 0.0994
# Epoch 238/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.0960e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0500 - val_mean_absolute_error: 0.0993
# Epoch 239/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 8.7457e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0498 - val_mean_absolute_error: 0.0991
# Epoch 240/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 8.6477e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 241/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.5943e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0499 - val_mean_absolute_error: 0.0991
# Epoch 242/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.6291e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0498 - val_mean_absolute_error: 0.0993
# Epoch 243/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 8.7960e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0498 - val_mean_absolute_error: 0.0992
# Epoch 244/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 8.9019e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0498 - val_mean_absolute_error: 0.0992
# Epoch 245/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 8.5535e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0497 - val_mean_absolute_error: 0.0989
# Epoch 246/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.4038e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0499 - val_mean_absolute_error: 0.0993
# Epoch 247/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.2223e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0498 - val_mean_absolute_error: 0.0992
# Epoch 248/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.6641e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0490 - val_mean_absolute_error: 0.0982
# Epoch 249/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.5009e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0500 - val_mean_absolute_error: 0.0993
# Epoch 250/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0333e-04 - mean_absolute_error: 0.0058 - val_loss: 0.0494 - val_mean_absolute_error: 0.0989
# Epoch 251/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.4489e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0494 - val_mean_absolute_error: 0.0989
# Epoch 252/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 9.1553e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0495 - val_mean_absolute_error: 0.0990
# Epoch 253/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 8.9704e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0495 - val_mean_absolute_error: 0.0990
# Epoch 254/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.1424e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0497 - val_mean_absolute_error: 0.0991
# Epoch 255/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.2188e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0496 - val_mean_absolute_error: 0.0991
# Epoch 256/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.1243e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0496 - val_mean_absolute_error: 0.0991
# Epoch 257/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 8.9603e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0497 - val_mean_absolute_error: 0.0989
# Epoch 258/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.0002e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0497 - val_mean_absolute_error: 0.0991
# Epoch 259/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.2608e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0498 - val_mean_absolute_error: 0.0992
# Epoch 260/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.3295e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0491 - val_mean_absolute_error: 0.0986
# Epoch 261/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 8.9791e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0494 - val_mean_absolute_error: 0.0989
# Epoch 262/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 8.5059e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0494 - val_mean_absolute_error: 0.0991
# Epoch 263/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 8.6734e-05 - mean_absolute_error: 0.0049 - val_loss: 0.0494 - val_mean_absolute_error: 0.0988
# Epoch 264/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.7522e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0497 - val_mean_absolute_error: 0.0993
# Epoch 265/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 9.4602e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0491 - val_mean_absolute_error: 0.0988
# Epoch 266/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.0306e-04 - mean_absolute_error: 0.0053 - val_loss: 0.0492 - val_mean_absolute_error: 0.0990
# Epoch 267/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 1.2129e-04 - mean_absolute_error: 0.0060 - val_loss: 0.0492 - val_mean_absolute_error: 0.0989
# Epoch 268/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 1.0526e-04 - mean_absolute_error: 0.0056 - val_loss: 0.0494 - val_mean_absolute_error: 0.0988
# Epoch 269/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.8404e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0494 - val_mean_absolute_error: 0.0990
# Epoch 270/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 9.6004e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0490 - val_mean_absolute_error: 0.0986
# Epoch 271/1000
# ...
# Epoch 912/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.8760e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0539 - val_mean_absolute_error: 0.1082
# Epoch 913/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.2710e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0536 - val_mean_absolute_error: 0.1081
# Epoch 914/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 6.9519e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0536 - val_mean_absolute_error: 0.1078
# Epoch 915/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.8335e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0536 - val_mean_absolute_error: 0.1080
# Epoch 916/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.3669e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0535 - val_mean_absolute_error: 0.1078
# Epoch 917/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 7.3818e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0537 - val_mean_absolute_error: 0.1080
# Epoch 918/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.2315e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0536 - val_mean_absolute_error: 0.1079
# Epoch 919/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.1663e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1079
# Epoch 920/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.5723e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0536 - val_mean_absolute_error: 0.1080
# Epoch 921/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.9016e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0535 - val_mean_absolute_error: 0.1079
# Epoch 922/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 6.9371e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0538 - val_mean_absolute_error: 0.1080
# Epoch 923/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.1635e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0537 - val_mean_absolute_error: 0.1081
# Epoch 924/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.9570e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0537 - val_mean_absolute_error: 0.1080
# Epoch 925/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 6.8827e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0536 - val_mean_absolute_error: 0.1079
# Epoch 926/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.2142e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1081
# Epoch 927/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.9840e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0536 - val_mean_absolute_error: 0.1080
# Epoch 928/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.3733e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0536 - val_mean_absolute_error: 0.1079
# Epoch 929/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.3262e-05 - mean_absolute_error: 0.0044 - val_loss: 0.0537 - val_mean_absolute_error: 0.1080
# Epoch 930/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.0465e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0538 - val_mean_absolute_error: 0.1080
# Epoch 931/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.4417e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0535 - val_mean_absolute_error: 0.1077
# Epoch 932/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.3395e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0537 - val_mean_absolute_error: 0.1079
# Epoch 933/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 7.4862e-05 - mean_absolute_error: 0.0044 - val_loss: 0.0535 - val_mean_absolute_error: 0.1079
# Epoch 934/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.5326e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0536 - val_mean_absolute_error: 0.1080
# Epoch 935/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.3855e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0535 - val_mean_absolute_error: 0.1079
# Epoch 936/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.3905e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0536 - val_mean_absolute_error: 0.1080
# Epoch 937/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.8793e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0535 - val_mean_absolute_error: 0.1080
# Epoch 938/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.7057e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0534 - val_mean_absolute_error: 0.1078
# Epoch 939/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 8.3099e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0535 - val_mean_absolute_error: 0.1083
# Epoch 940/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 9.0089e-05 - mean_absolute_error: 0.0048 - val_loss: 0.0536 - val_mean_absolute_error: 0.1081
# Epoch 941/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 9.6653e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0536 - val_mean_absolute_error: 0.1084
# Epoch 942/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 9.1915e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0536 - val_mean_absolute_error: 0.1080
# Epoch 943/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 8.0373e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0537 - val_mean_absolute_error: 0.1082
# Epoch 944/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.5849e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0537 - val_mean_absolute_error: 0.1083
# Epoch 945/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.1977e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0534 - val_mean_absolute_error: 0.1081
# Epoch 946/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.1854e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0537 - val_mean_absolute_error: 0.1082
# Epoch 947/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.8026e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0534 - val_mean_absolute_error: 0.1080
# Epoch 948/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.7493e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0537 - val_mean_absolute_error: 0.1080
# Epoch 949/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 8.0143e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0537 - val_mean_absolute_error: 0.1082
# Epoch 950/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.4343e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0537 - val_mean_absolute_error: 0.1083
# Epoch 951/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.2904e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0537 - val_mean_absolute_error: 0.1082
# Epoch 952/1000
# 11252/11252 [==============================] - 7s 587us/step - loss: 6.9097e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0537 - val_mean_absolute_error: 0.1082
# Epoch 953/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.7234e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0539 - val_mean_absolute_error: 0.1082
# Epoch 954/1000
# 11252/11252 [==============================] - 7s 592us/step - loss: 6.9587e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0536 - val_mean_absolute_error: 0.1083
# Epoch 955/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.3414e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0535 - val_mean_absolute_error: 0.1081
# Epoch 956/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.3920e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0533 - val_mean_absolute_error: 0.1080
# Epoch 957/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.6830e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0534 - val_mean_absolute_error: 0.1082
# Epoch 958/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.7752e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0535 - val_mean_absolute_error: 0.1082
# Epoch 959/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 6.8229e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0535 - val_mean_absolute_error: 0.1080
# Epoch 960/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 6.5685e-05 - mean_absolute_error: 0.0038 - val_loss: 0.0536 - val_mean_absolute_error: 0.1081
# Epoch 961/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 6.6259e-05 - mean_absolute_error: 0.0038 - val_loss: 0.0534 - val_mean_absolute_error: 0.1080
# Epoch 962/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.0957e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0534 - val_mean_absolute_error: 0.1081
# Epoch 963/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.2622e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0534 - val_mean_absolute_error: 0.1078
# Epoch 964/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.7422e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0533 - val_mean_absolute_error: 0.1083
# Epoch 965/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.5613e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0537 - val_mean_absolute_error: 0.1084
# Epoch 966/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.4716e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0534 - val_mean_absolute_error: 0.1080
# Epoch 967/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.5014e-05 - mean_absolute_error: 0.0044 - val_loss: 0.0536 - val_mean_absolute_error: 0.1081
# Epoch 968/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.1240e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1083
# Epoch 969/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.2883e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1084
# Epoch 970/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.2020e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0532 - val_mean_absolute_error: 0.1079
# Epoch 971/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.0991e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0535 - val_mean_absolute_error: 0.1084
# Epoch 972/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 6.9658e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0536 - val_mean_absolute_error: 0.1083
# Epoch 973/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.0418e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0536 - val_mean_absolute_error: 0.1082
# Epoch 974/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.1389e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0534 - val_mean_absolute_error: 0.1082
# Epoch 975/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.6345e-05 - mean_absolute_error: 0.0044 - val_loss: 0.0536 - val_mean_absolute_error: 0.1086
# Epoch 976/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.5431e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0532 - val_mean_absolute_error: 0.1080
# Epoch 977/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.8069e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0537 - val_mean_absolute_error: 0.1086
# Epoch 978/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.3207e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1085
# Epoch 979/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.2747e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0535 - val_mean_absolute_error: 0.1083
# Epoch 980/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.4389e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0536 - val_mean_absolute_error: 0.1084
# Epoch 981/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.1768e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1084
# Epoch 982/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.9791e-05 - mean_absolute_error: 0.0048 - val_loss: 0.0535 - val_mean_absolute_error: 0.1083
# Epoch 983/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.5584e-05 - mean_absolute_error: 0.0044 - val_loss: 0.0536 - val_mean_absolute_error: 0.1085
# Epoch 984/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.6709e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0535 - val_mean_absolute_error: 0.1082
# Epoch 985/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.2719e-05 - mean_absolute_error: 0.0043 - val_loss: 0.0535 - val_mean_absolute_error: 0.1082
# Epoch 986/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.9665e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0535 - val_mean_absolute_error: 0.1084
# Epoch 987/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.0561e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0537 - val_mean_absolute_error: 0.1086
# Epoch 988/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.3043e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1086
# Epoch 989/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.1289e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0536 - val_mean_absolute_error: 0.1086
# Epoch 990/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.2349e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0536 - val_mean_absolute_error: 0.1085
# Epoch 991/1000
# 11252/11252 [==============================] - 7s 591us/step - loss: 6.8339e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0535 - val_mean_absolute_error: 0.1084
# Epoch 992/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.6257e-05 - mean_absolute_error: 0.0039 - val_loss: 0.0536 - val_mean_absolute_error: 0.1085
# Epoch 993/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 7.0451e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0533 - val_mean_absolute_error: 0.1083
# Epoch 994/1000
# 11252/11252 [==============================] - 7s 590us/step - loss: 7.6775e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0537 - val_mean_absolute_error: 0.1085
# Epoch 995/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.9899e-05 - mean_absolute_error: 0.0047 - val_loss: 0.0533 - val_mean_absolute_error: 0.1083
# Epoch 996/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 6.8780e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0537 - val_mean_absolute_error: 0.1087
# Epoch 997/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 6.9833e-05 - mean_absolute_error: 0.0040 - val_loss: 0.0536 - val_mean_absolute_error: 0.1085
# Epoch 998/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 7.6619e-05 - mean_absolute_error: 0.0045 - val_loss: 0.0539 - val_mean_absolute_error: 0.1086
# Epoch 999/1000
# 11252/11252 [==============================] - 7s 589us/step - loss: 8.0258e-05 - mean_absolute_error: 0.0046 - val_loss: 0.0536 - val_mean_absolute_error: 0.1084
# Epoch 1000/1000
# 11252/11252 [==============================] - 7s 588us/step - loss: 9.0396e-05 - mean_absolute_error: 0.0049 - val_loss: 0.0537 - val_mean_absolute_error: 0.1087

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_1000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_2000.h5')

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_2000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_3000.h5')

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_3000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_4000.h5')

# %%
model = load_model('drive/facial-landmark-detection/CNN_4_4000.h5')
print "[INFO] Training"
hist = model.fit(X, Y, validation_split=0.2, shuffle=True, epochs=1000, batch_size=512)
generate(hist.history)
model.save('drive/facial-landmark-detection/CNN_4_5000.h5')
